# %% [markdown]
# <a href="https://colab.research.google.com/github/kumargauravpant/ML-Foundations-HandsOn/blob/main/1_intro_to_linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,40,100) #start, end, n points

# %%
d_r = 2.5 * t

# %%
d_s = 3 * (t-5)

# %%
fig, ax = plt.subplots()
plt.title('A Bank Robber Caught')
plt.xlabel('time (in minutes)')
plt.ylabel('distance (in km)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='brown')
plt.axvline(x=30, color='purple', linestyle='--')
_ = plt.axhline(y=75, color='purple', linestyle='--')

# %% [markdown]
# ### Scalers (rank 0 tensors)

# %%
x=25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Scalers in PyTorch

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# ### Scalers in TensorFlow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype=tf.int16)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(10, dtype=tf.int16)

# %%
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=10>

# %%
z_tf = x_tf + y_tf
z_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=35>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=35>

# %%
tf_float = tf.Variable(12, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=12.0>
